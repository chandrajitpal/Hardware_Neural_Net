# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrajitpal/Hardware_Neural_Net/blob/master/01_cuda_lab/01_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple C Programming with Google Colab
#
# - Instructir: Jeong-Gun Lee (School of Software, Hallym University)
# - Email: jeonggun.lee@gmail.com
# - Web: http://www.onchp.net

# %% [markdown]
# You can make a simple C code with the name of **codename.c** through [ %%writefile codename.c ]

# %% [markdown]
# CYBERSECURITY: LAB 1

# %% [markdown]
# Supervised learning example – linear regression

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

pool = np.random.RandomState(10)
x = 5 * pool.rand(30)
y = 3 * x - 2 + pool.randn(30)

# y = 3x - 2;
lregr = LinearRegression(fit_intercept=False)

X = x[:, np.newaxis]
lregr.fit(X, y)

lspace = np.linspace(0, 5)
X_regr = lspace[:, np.newaxis]
y_regr = lregr.predict(X_regr)

plt.scatter(x, y);
plt.plot(X_regr, y_regr);

# %% [markdown]
# Unsupervised Learning Example: Clustering

# %%
import pandas as pd
import seaborn as sns


from google.colab import drive
drive.mount('/content/drive')





file_path = '/content/drive/My Drive/clustering.csv'

data_df = pd.read_csv(file_path)
data_df.describe()

X_data = data_df.drop('class_1', axis=1)
y_data = data_df['class_1']

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(X_data)
X_2D = pca.transform(X_data)
data_df['PCA1'] = X_2D[:, 0]
data_df['PCA2'] = X_2D[:, 1]

from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=3, covariance_type='full')
gm.fit(X_data)

y_gm = gm.predict(X_data)
data_df['cluster'] = y_gm

sns.lmplot(x="PCA1", y="PCA2", data=data_df, col='cluster', fit_reg=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Simple Neural Network Example: Perceptron

# %%
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.pyplot as plt



# Thanks to Sebastian Raschka for 'plot_decision_regions' function

def plot_decision_regions(X, y, classifier, resolution=0.02):

# setup marker generator and color map

  markers = ('s', 'x', 'o', '^', 'v')
  colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
  cmap = ListedColormap(colors[:len(np.unique(y))])

  # plot the decision surface

  x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
  x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
  xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),

  np.arange(x2_min, x2_max, resolution))

  Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
  Z = Z.reshape(xx1.shape)
  plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
  plt.xlim(xx1.min(), xx1.max())
  plt.ylim(xx2.min(), xx2.max())

  # plot class samples

  for idx, cl in enumerate(np.unique(y)):

    plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
    alpha=0.8, color=cmap(idx),
    marker=markers[idx], label=cl)

from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=30, n_features=2, n_informative=2, n_redundant=0, weights=[.3, .3], random_state=300)
plt.scatter(X[:,0], X[:,1], s=50)
pct = Perceptron(max_iter=100, verbose=0, random_state=300,
fit_intercept=True, eta0=0.002)
pct.fit(X, y)
plot_decision_regions(X, y, classifier=pct)
plt.title('Perceptron')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
